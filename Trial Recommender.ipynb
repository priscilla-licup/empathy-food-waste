# %% [markdown]
# # Recipe Recommender System

# %% [markdown]
# ## Dataset Description
#
# The dataset, structured in a user-friendly CSV format, comprises detailed information on recipes that users have published on Food.com. Here's the columns of the dataset:
#
# 1. Basic Information:
# - id: Unique identifier for each recipe.
# - name: The title of the recipe.
# - description: A brief overview of the recipe.
#
# 2. Detailed Recipe Breakdown:
# - steps: Step-by-step cooking instructions.
#
# 3. Ingredient Insights:
# - ingredients_raw: Original list of ingredients as written in the recipe.
# - ingredients: Cleaned and processed list of ingredients.
#
# 4. Additional Details:
# - servings: Suggested number of servings.
# - serving_size: The amount per serving.
# - tags: Keywords associated with the recipe (e.g., vegan, quick, summer).
#
# Data : https://www.kaggle.com/datasets/realalexanderwei/food-com-recipes-with-ingredients-and-tags?resource=download

# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

import os
from collections import Counter
import ast

# %%
data_folder = 'C:\\Users\\Solid State Drive\\Documents\\GitHub\\empathy-food-waste'
file_path = os.path.join(data_folder, 'recipes_ingredients.csv')

orig_df = pd.read_csv(file_path)
df = pd.read_csv(file_path)

# %%
df
# Out:
#             id                                               name  \
# 0        71247                            Cherry Streusel Cobbler
# 1        76133                    Reuben and Swiss Casserole Bake
# 2       503816                                   Yam-Pecan Recipe
# 3       418749                        Tropical  Orange Layer Cake
# 4       392934  Safe to Eat Raw Chocolate Chip Oreo Cookie &qu...
# ...        ...                                                ...
# 500466  173790                              Sausage Meatloaf OAMC
# 500467  301838       Potato Salad With Olives Capers and Parmesan
# 500468  130682                        Chocolate Banana Pound Cake
# 500469  353659              Cheesy Ground Beef and Rice Casserole
# 500470  510848            Chicken and Dumplings &ndash; Crock Pot
#
#                                               description  \
# 0       I haven't made this in years, so I'm just gues...
# 1       I think this is even better than a reuben sand...
# 2       A lady I work with heard me taking about ZWT a...
# 3       An easy and delicious cake.  Great for a  summ...
# 4       I was searching the web for something like thi...
# ...                                                   ...
# 500466  I grew up on this meatloaf, and I love it.  It...
# 500467                                     Cooking Light.
# 500468  This recipe was passed to me by my mother, and...
# 500469  This is one of those comfort food dishes I cre...
# 500470  Fix it and Forget it Lightly â€“ Slow Cooker r...
#
#                                               ingredients  \
# 0       ["cherry pie filling", "condensed milk", "melt...
# 1       ["corned beef chopped", "sauerkraut cold water...
# 2       ["unsalted butter", "vegetable oil", "all - pu...
# 3       ["orange cake mix", "instant vanilla pudding",...
# 4       ["butter", "brown sugar", "granulated sugar", ...
# ...                                                   ...
# 500466  ["ground beef", "ground sausage", "celery chop...
# 500467  ["red potatoes", "fresh ground black pepper", ...
# 500468  ["butter", "brown sugar", "bananas", "buttermi...
# 500469  ["ground beef", "medium onion chopped", "brown...
# 500470  ["chicken cubed", "frozen vegetables", "onion"...
#
#                                           ingredients_raw  \
# 0       ["2 (21   ounce) cans   cherry pie filling","2...
# 1       ["1/2-1   lb    corned beef, cooked and choppe...
# 2       ["3/4  cup    unsalted butter, at room tempera...
# 3       ["1 (18   ounce)   pkge.orange cake mix","1 (3...
# 4       ["1/2  cup    butter, room temperature ","1/2 ...
# ...                                                   ...
# 500466  ["1   lb    lean ground beef","1/2  lb    grou...
# 500467  ["3   lbs    small red potatoes","2   tablespo...
# 500468  ["1   cup    butter (room temperature)","2   l...
# 500469  ["1 1/2  lbs    ground beef","1   medium    on...
# 500470  ["1   lb    chicken, cubed ","1   lb    frozen...
#
#                                                     steps  servings  \
# 0       ["Preheat oven to 375Â°F.", "Spread cherry pie...       6.0
# 1       ["Set oven to 350 degrees F.", "Butter a 9 x 1...       4.0
# 2       ["Preheat oven to 350Â°F  In a mixing bowl, us...       8.0
# 3       ["In a large mixing bowl, combine the first 6 ...      16.0
# 4       ["Cream butter and sugars together.", "Blend i...      24.0
# ...                                                   ...       ...
# 500466  ["Combine ground beef, sausage, celery, onion,...       6.0
# 500467  ["Preheat oven to 375Â°.", "To prepare potatoe...       8.0
# 500468  ["Preheat oven to 350 degrees.", "Grease and f...      24.0
# 500469  ["*What I mean by "partly drained" with the mu...       6.0
# 500470  ["Combine chicken, vegetables, onion and chick...       6.0
#
#        serving_size                                               tags
# 0         1 (347 g)  ["60-minutes-or-less", "time-to-make", "course...
# 1         1 (207 g)  ["60-minutes-or-less", "time-to-make", "course...
# 2         1 (198 g)  ["time-to-make", "course", "main-ingredient", ...
# 3         1 (191 g)  ["60-minutes-or-less", "time-to-make", "course...
# 4          1 (26 g)  ["15-minutes-or-less", "time-to-make", "course...
# ...             ...                                                ...
# 500466    1 (244 g)  ["time-to-make", "course", "main-ingredient", ...
# 500467    1 (223 g)  ["time-to-make", "course", "main-ingredient", ...
# 500468     1 (99 g)  ["time-to-make", "course", "main-ingredient", ...
# 500469    1 (394 g)  ["60-minutes-or-less", "time-to-make", "prepar...
# 500470    1 (323 g)  ["course", "preparation", "5-ingredients-or-le...
#
# [500471 rows x 9 columns]

# %%
df.dtypes
# Out:
# id                   int64
# name                object
# description         object
# ingredients         object
# ingredients_raw     object
# steps               object
# servings           float64
# serving_size        object
# tags                object
# dtype: object

# %% [markdown]
# ### Datatype Conversion

# %%
df['id'] = df['id'].astype(str)
df['name'] = df['name'].astype(str)
df['description'] = df['description'].astype(str)
df['serving_size'] = df['serving_size'].astype(str)

# %%
# Convert lists to strings to check duplicates
df['tags'] = df['tags'].apply(lambda x: str(x) if isinstance(x, list) else x)
df['ingredients	'] = df['ingredients'].apply(lambda x: str(x) if isinstance(x, list) else x)
df['ingredients_raw'] = df['ingredients_raw'].apply(lambda x: str(x) if isinstance(x, list) else x)
df['steps'] = df['steps'].apply(lambda x: str(x) if isinstance(x, list) else x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500471 entries, 0 to 500470
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               500471 non-null  object
#  1   name             500471 non-null  object
#  2   description      500471 non-null  object
#  3   ingredients      500471 non-null  object
#  4   ingredients_raw  500436 non-null  object
#  5   steps            500471 non-null  object
#  6   servings         499749 non-null  float64
#  7   serving_size     500471 non-null  object
#  8   tags             500436 non-null  object
#  9   ingredients	     500471 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 38.2+ MB

# %% [markdown]
# ### Cleaning

# %%
# Drop missing rows 
# ----------------------
# do we still need?
# we can still display recipes without tags or specified servings?

# %% [markdown]
# ### Duplication

# %%
# Duplicated rows
print("duplicated rows in recipes dataset:", df.duplicated().sum())
# Out:
# duplicated rows in recipes dataset: 0

# %%
# Convert back to original for processing later
df['tags'] = orig_df['tags']
df['ingredients'] = orig_df['ingredients']
df['ingredients_raw'] = orig_df['ingredients_raw']
df['steps'] = orig_df['steps']

# %% [markdown]
# ### Count Unique Tags

# %% [markdown]
# Might need to revise as a data contains malformed string (" and \ problems). A placeholder is used for now

# %%
def safe_literal_eval(s):
    # Check for NaN values first to avoid trying to parse them
    if pd.isna(s):
        return s  # Return NaN as is, or you can choose to return an empty list or another placeholder
    
    try:
        # Attempt to parse string using ast.literal_eval
        return ast.literal_eval(s)
    except (ValueError, SyntaxError):  # Catch syntax errors in addition to value errors
        return []

# %%
df['tags'] = df['tags'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df['ingredients'] = df['ingredients'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# Did not convert other columns first as they contain syntax errors(?)

# %%
# # Convert strings back to lists for accessibility
# df['ingredients'] = df['ingredients'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
# df['ingredients_raw'] = df['ingredients_raw'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
# df['steps'] = df['steps'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
# Now, extract all tags from the DataFrame's 'tags' column
# This also includes a check to ensure we only attempt to iterate over lists
all_tags = [tag for sublist in df['tags'] if isinstance(sublist, list) for tag in sublist]

# Count the occurrence of each tag
tags_counter = Counter(all_tags)

# Sort tags alphabetically and prepare a list of tuples with tag and its count
sorted_tags_with_count = sorted(tags_counter.items())

sorted_tags_with_count
# Out:
# [('', 388),
#  (' juice and zest of', 1),
#  (' recipes', 2),
#  (' recipies', 2),
#  ('1-day-or-more', 4956),
#  ('15-minutes-or-less', 84516),
#  ('3-steps-or-less', 105146),
#  ('30-minutes-or-less', 117567),
#  ('4-hours-or-less', 113460),
#  ('5-ingredients-or-less', 71605),
#  ('60-minutes-or-less', 155872),
#  ('Cool Whip', 1),
#  ('Throw the ultimate fiesta with this sopaipillas recipe from Food.com.', 1),
#  ('a1-sauce', 103),
#  ('african', 4598),
#  ('american', 62117),
#  ('amish-mennonite', 349),
#  ('angolan', 19),
#  ('appetizers', 45980),
#  ('appetizers-seafood', 1),
#  ('apple-pie', 1),
#  ('apples', 9565),
#  ('april-fools-day', 23),
#  ('argentine', 198),
#  ('artichoke', 183),
#  ('asian', 27195),
#  ('asparagus', 2891),
#  ('australian', 5040),
#  ('austrian', 320),
#  ('avocado', 406),
#  ('bacon', 3217),
#  ('baja', 319),
#  ('baked-beans', 1),
#  ('baking', 1272),
#  ('bananas', 4041),
#  ('bar-cookies', 7126),
#  ('barbecue', 6757),
#  ('bass', 168),
#  ('bath-beauty', 41),
#  ('bean-soup', 5),
#  ('beans', 19493),
#  ('beans-side-dishes', 2),
#  ('beans-soups', 4),
#  ('bear', 13),
#  ('beef', 34741),
#  ('beef-barley-soup', 1),
#  ('beef-crock-pot', 1),
#  ('beef-kidney', 13),
#  ('beef-liver', 163),
#  ('beef-organ-meats', 280),
#  ('beef-ribs', 463),
#  ('beef-sandwiches', 1),
#  ('beef-sauces', 1),
#  ('beef-sausage', 801),
#  ('beginner-cook', 65970),
#  ('beijing', 45),
#  ('belgian', 281),
#  ('berries', 11619),
#  ('beverages', 16434),
#  ('birthday', 1060),
#  ('biscotti', 551),
#  ('bisques-cream-soups', 4129),
#  ('bizarre', 581),
#  ('black-bean-soup', 1),
#  ('black-beans', 3096),
#  ('blueberries', 2743),
#  ('bok-choys', 201),
#  ('brazilian', 426),
#  ('bread-machine', 1773),
#  ('bread-pudding', 1),
#  ('breads', 28398),
#  ('breakfast', 28860),
#  ('breakfast-casseroles', 1),
#  ('breakfast-eggs', 4),
#  ('breakfast-potatoes', 1),
#  ('brewing', 101),
#  ('brisket', 3),
#  ('british-columbian', 1041),
#  ('broccoli', 4151),
#  ('broccoli-soup', 1),
#  ('broil', 3007),
#  ('brown sugar', 1),
#  ('brown-bag', 5592),
#  ('brown-rice', 1412),
#  ('brownies', 2175),
#  ('brunch', 36340),
#  ('burgers', 835),
#  ('butter', 1),
#  ('cabbage', 2),
#  ('cajun', 2482),
#  ('cake-fillings-and-frostings', 3012),
#  ('cakes', 23086),
#  ('californian', 1408),
#  ('cambodian', 87),
#  ('camping', 2833),
#  ('canadian', 7986),
#  ('candy', 5477),
#  ('canned chipotle chiles', 1),
#  ('canning', 1750),
#  ('cantonese', 309),
#  ('caribbean', 3006),
#  ('carrots', 5743),
#  ('casseroles', 13115),
#  ('casseroles-one-dish-meal', 1),
#  ('catfish', 392),
#  ('cauliflower', 2238),
#  ('celebrity', 1060),
#  ('central-american', 2967),
#  ('chard', 236),
#  ('cheese', 28037),
#  ('cheesecake', 4052),
#  ('cherries', 1167),
#  ('chick-peas-garbanzos', 2292),
#  ('chicken', 41434),
#  ('chicken-breasts', 16654),
#  ('chicken-crock-pot', 1),
#  ('chicken-livers', 202),
#  ('chicken-stew', 1),
#  ('chicken-stews', 1),
#  ('chicken-thighs-legs', 3196),
#  ('chilean', 131),
#  ('chili', 4396),
#  ('chili powder', 1),
#  ('chinese', 4327),
#  ('chinese-new-year', 48),
#  ('chocolate', 19542),
#  ('chocolate-chip-cookies', 317),
#  ('chowders', 2005),
#  ('christmas', 15344),
#  ('christmas-cookies', 1),
#  ('chutneys', 383),
#  ('cinco-de-mayo', 265),
#  ('citrus', 7545),
#  ('clams', 742),
#  ('clear-soups', 1460),
#  ('cobblers-and-crisps', 2722),
#  ('cocktails', 5731),
#  ('coconut', 3215),
#  ('coconut-cream-pie', 1),
#  ('coconut-desserts', 1),
#  ('cod', 740),
#  ('coffee-cakes', 2049),
#  ('collard-greens', 245),
#  ('college', 56),
#  ('colombian', 155),
#  ('comfort-food', 47544),
#  ('condiments-etc', 22054),
#  ('congolese', 15),
#  ('cookie', 2),
#  ('cookies-and-brownies', 28127),
#  ('cookies-and-brownies-holiday-event', 1),
#  ('cookies-and-brownies-nuts', 2),
#  ('cooking-mixes', 1518),
#  ('copycat', 3298),
#  ('corn', 4803),
#  ('costa-rican', 70),
#  ('course', 470603),
#  ('crab', 3152),
#  ('cranberry-sauce', 1),
#  ('crawfish', 309),
#  ('creole', 1847),
#  ('crock-pot-main-dish', 4),
#  ('crock-pot-slow-cooker', 11872),
#  ('crusts-pastry-dough-2', 987),
#  ('cuban', 468),
#  ('cuisine', 183717),
#  ('cupcakes', 2164),
#  ('curries', 2847),
#  ('curries-indian', 1),
#  ('czech', 248),
#  ('dairy-free', 348),
#  ('danish', 409),
#  ('deep-fry', 2137),
#  ('deer', 540),
#  ('dehydrator', 112),
#  ('desserts', 105877),
#  ('desserts-easy', 1),
#  ('desserts-fruit', 1),
#  ('diabetic', 13335),
#  ('dietary', 332195),
#  ('dinner-party', 73369),
#  ('dips', 11235),
#  ('dips-lunch-snacks', 22),
#  ('dips-summer', 1),
#  ('drop-cookies', 6396),
#  ('duck', 418),
#  ('duck-breasts', 125),
#  ('dutch', 401),
#  ('easter', 4090),
#  ('easy', 263078),
#  ('ecuadorean', 70),
#  ('egg whites', 1),
#  ('egg-free', 9769),
#  ('eggplant', 321),
#  ('eggs', 17531),
#  ('eggs-breakfast', 3),
#  ('eggs-dairy', 57622),
#  ('egyptian', 286),
#  ('elbow-macaroni', 2853),
#  ('elk', 87),
#  ('english', 3611),
#  ('equipment', 122487),
#  ('ethiopian', 122),
#  ('european', 50514),
#  ('fall', 14077),
#  ('fathers-day', 74),
#  ('filipino', 422),
#  ('fillings-and-frostings-chocolate', 128),
#  ('fillings-and-frostings-fruit', 1),
#  ('finger-food', 11702),
#  ('finnish', 250),
#  ('fish', 14910),
#  ('fish-halibut', 1),
#  ('fish-salmon', 1),
#  ('fish-tuna', 1),
#  ('flat-shapes', 1211),
#  ('food-processor-blender', 8371),
#  ('for-1-or-2', 44405),
#  ('for-large-groups', 40341),
#  ('for-large-groups-holiday-event', 1),
#  ('fourth-of-july', 20),
#  ('free-of-something', 23579),
#  ('freezer', 2900),
#  ('freezer-desserts', 2),
#  ('freezer-served-cold', 2),
#  ('french', 4904),
#  ('freshwater-fish', 1738),
#  ('from-scratch', 10132),
#  ('frozen-desserts', 5248),
#  ('fruit', 60747),
#  ('fudge', 1450),
#  ('garlic cloves', 1),
#  ('garnishes', 931),
#  ('gelatin', 1522),
#  ('gelatin-fruit', 1),
#  ('georgian', 42),
#  ('german', 2582),
#  ('gifts', 12747),
#  ('gluten-free', 11637),
#  ('gluten-free-appetizers', 1),
#  ('goose', 45),
#  ('grains', 11234),
#  ('granola-and-porridge', 2094),
#  ('grapes', 485),
#  ('greek', 4210),
#  ('greek-dinner-party', 1),
#  ('green food coloring recipe', 1),
#  ('green-yellow-beans', 2591),
#  ('greens', 7871),
#  ('greens-spinach', 1),
#  ('grilling', 8418),
#  ('ground-beef', 16371),
#  ('ground-beef-main-dish', 1),
#  ('guatemalan', 46),
#  ('gumbo', 471),
#  ('halibut', 596),
#  ('halloween', 1526),
#  ('halloween-cakes', 15),
#  ('halloween-cocktails', 11),
#  ('halloween-cupcakes', 20),
#  ('ham', 3306),
#  ('hand-formed-cookies', 4129),
#  ('hanukkah', 1072),
#  ('hawaiian', 839),
#  ('healthy', 84564),
#  ('healthy-2', 54859),
#  ('heirloom-historical', 8544),
#  ('heirloom-historical-recipes', 16),
#  ('herb-and-spice-mixes', 1065),
#  ('hidden-valley-ranch', 304),
#  ('high-calcium', 9943),
#  ('high-fiber', 584),
#  ('high-in-something', 22557),
#  ('high-in-something-diabetic-friendly', 1),
#  ('high-protein', 14048),
#  ('holiday-event', 66842),
#  ('homeopathy-remedies', 25),
#  ('honduran', 31),
#  ('hot-dogs', 1),
#  ('household-cleansers', 29),
#  ('hunan', 56),
#  ('hungarian', 590),
#  ('ice-cream', 401),
#  ('icelandic', 81),
#  ('independence-day', 3822),
#  ('indian', 6349),
#  ('indonesian', 388),
#  ('inexpensive', 64785),
#  ('infant-baby-friendly', 818),
#  ('iranian-persian', 403),
#  ('iraqi', 137),
#  ('irish', 1251),
#  ('irish-st-patricks-day', 1),
#  ('italian', 15674),
#  ('jams-and-preserves', 1445),
#  ('japanese', 1932),
#  ('jellies', 309),
#  ('jewish-ashkenazi', 1251),
#  ('jewish-sephardi', 328),
#  ('key-lime-pie', 1),
#  ('kid-friendly', 51702),
#  ('kiwifruit', 277),
#  ('korean', 555),
#  ('kosher', 8203),
#  ('kosher salt', 1),
#  ('kwanzaa', 524),
#  ('labor-day', 160),
#  ('lactose', 7737),
#  ('lamb-sheep', 3290),
#  ('lamb-sheep-main-dish', 2),
#  ('laotian', 57),
#  ('lasagna', 2014),
#  ('lasagne', 1),
#  ('lebanese', 493),
#  ('leftovers', 1377),
#  ('lemon', 3167),
#  ('lemon-cake', 2),
#  ('lemon-desserts', 1),
#  ('lentils', 2346),
#  ('less_thansql:name_topics_of_recipegreater_than', 1),
#  ('lettuces', 1748),
#  ('libyan', 62),
#  ('lime', 1165),
#  ('lime yogurt', 1),
#  ('lime zest', 1),
#  ('lime-desserts', 1),
#  ('limes', 1),
#  ('lobster', 482),
#  ('long-grain-rice', 2303),
#  ('low-calorie', 76466),
#  ('low-carb', 89268),
#  ('low-cholesterol', 77516),
#  ('low-fat', 45819),
#  ('low-in-something', 182366),
#  ('low-protein', 69889),
#  ('low-saturated-fat', 66280),
#  ('low-sodium', 94489),
#  ('lunch', 45128),
#  ('macaroni-and-cheese', 267),
#  ('mahi-mahi', 182),
#  ('main-dish', 152459),
#  ('main-dish-beef', 8),
#  ('main-dish-casseroles', 1),
#  ('main-dish-chicken', 8),
#  ('main-dish-crock-pot', 1),
#  ('main-dish-pasta', 3),
#  ('main-dish-pork', 8),
#  ('main-dish-seafood', 2),
#  ('main-ingredient', 348022),
#  ('malaysian', 249),
#  ('mango', 1349),
#  ('manicotti', 296),
#  ('mardi-gras-carnival', 628),
#  ('margarine', 2),
#  ('margarita', 1),
#  ('margarita mix', 1),
#  ('marinades-and-rubs', 2007),
#  ('marinara-sauce', 2),
#  ('mashed-potatoes', 396),
#  ('meat', 114861),
#  ('meatballs', 416),
#  ('meatloaf', 463),
#  ('medium-grain-rice', 238),
#  ('melons', 1341),
#  ('memorial-day', 161),
#  ('mexican', 14813),
#  ('micro-melanesia', 92),
#  ('microwave', 3641),
#  ('middle-eastern', 3651),
#  ('middle-eastern-main-dish', 1),
#  ('midwestern', 6117),
#  ('mixer', 3258),
#  ('mongolian', 32),
#  ('moose', 50),
#  ('moroccan', 1514),
#  ('mothers-day', 178),
#  ('muffins', 5147),
#  ('mushroom-soup', 1),
#  ('mushrooms', 6565),
#  ('mussels', 498),
#  ('namibian', 13),
#  ('native-american', 343),
#  ('navy-bean-soup', 1),
#  ('nepalese', 92),
#  ('new-years', 4154),
#  ('new-zealand', 1227),
#  ('nigerian', 61),
#  ('no-bake-cookies', 1),
#  ('no-cook', 10470),
#  ('no-shell-fish', 363),
#  ('non-alcoholic', 671),
#  ('non-food-products', 116),
#  ('north-american', 95330),
#  ('northeastern-united-states', 4646),
#  ('norwegian', 371),
#  ('novelty', 8279),
#  ('number-of-servings', 116125),
#  ('nut-free', 987),
#  ('nuts', 13910),
#  ('oamc-freezer-make-ahead', 9076),
#  ('oatmeal', 223),
#  ('oaxacan', 148),
#  ('occasion', 226727),
#  ('octopus', 35),
#  ('omelets-and-frittatas', 2565),
#  ('one-dish-meal', 34534),
#  ('onions', 10176),
#  ('onions-side-dishes', 1),
#  ('ontario', 1367),
#  ('orange-roughy', 131),
#  ('oranges', 2683),
#  ('oven', 54480),
#  ('oysters', 516),
#  ('pacific-northwest', 1365),
#  ('pakistani', 373),
#  ('palestinian', 133),
#  ('pancakes-and-waffles', 4857),
#  ('papaya', 307),
#  ('passover', 885),
#  ('pasta', 25477),
#  ('pasta-elbow-macaroni', 11),
#  ('pasta-rice-and-grains', 53650),
#  ('pasta-rice-and-grains-elbow-macaroni', 2),
#  ('pasta-salad', 2),
#  ('pasta-shells', 1025),
#  ('peaches', 1759),
#  ('peanut-butter', 798),
#  ('peanut-butter-pie', 1),
#  ('pears', 1437),
#  ('penne', 2034),
#  ('pennsylvania-dutch', 356),
#  ('peppers', 6556),
#  ('perch', 36),
#  ('peruvian', 245),
#  ('pet-food', 470),
#  ('pheasant', 72),
#  ('pickeral', 8),
#  ('picnic', 13159),
#  ('pies', 7975),
#  ('pies-and-tarts', 12368),
#  ('pies-chocolate', 1),
#  ('pineapple', 4247),
#  ('pitted-fruit', 3804),
#  ('pizza', 3345),
#  ('plums', 379),
#  ('polish', 707),
#  ('polynesian', 348),
#  ('pork', 24548),
#  ('pork-chops', 2925),
#  ('pork-chops-marinades-and-rubs', 2),
#  ('pork-crock-pot', 1),
#  ('pork-loin', 1),
#  ('pork-loins', 2326),
#  ('pork-loins-roast', 1),
#  ('pork-ribs', 1073),
#  ('pork-sausage', 4187),
#  ('portuguese', 627),
#  ('pot-pie', 154),
#  ('pot-roast', 5),
#  ('potato-soup', 1),
#  ('potatoes', 20168),
#  ('potluck', 18615),
#  ('poultry', 49864),
#  ('preparation', 496606),
#  ('prepared-potatoes', 34),
#  ('presentation', 46002),
#  ('pressure-canning', 75),
#  ('pressure-cooker', 605),
#  ('pretzels', 1),
#  ('puddings-and-mousses', 6123),
#  ('puerto-rican', 212),
#  ('pumpkin', 472),
#  ('pumpkin-bread', 1),
#  ('punch', 1655),
#  ('quail', 56),
#  ('quebec', 375),
#  ('queso-for-all', 2),
#  ('quiche', 116),
#  ('quick-breads', 11078),
#  ('rabbit', 127),
#  ('ragu-recipe-contest', 137),
#  ('ramadan', 429),
#  ('raspberries', 2148),
#  ('ravioli-tortellini', 1330),
#  ('refrigerator', 8610),
#  ('reynolds-wrap', 217),
#  ('rice', 11885),
#  ('roast', 1946),
#  ('roast-beef', 2423),
#  ('roast-beef-comfort-food', 2),
#  ('roast-beef-crock-pot', 1),
#  ('roast-beef-main-dish', 1),
#  ('rolled-cookies', 2251),
#  ('rolls-biscuits', 3343),
#  ('romantic', 9263),
#  ('rosh-hashana', 609),
#  ('rosh-hashanah', 66),
#  ('russian', 842),
#  ('salad-dressings', 4140),
#  ('salads', 30582),
#  ('salmon', 4301),
#  ('salsas', 1513),
#  ('saltwater-fish', 10003),
#  ('sandwiches', 11042),
#  ('sauces', 10914),
#  ('saudi-arabian', 132),
#  ('savory', 20114),
#  ('savory-pies', 3226),
#  ('savory-sauces', 3651),
#  ('scallops', 1192),
#  ('scandinavian', 2253),
#  ('scones', 1153),
#  ('scottish', 1284),
#  ('seafood', 31509),
#  ('seasonal', 41405),
#  ('served-cold', 14388),
#  ('served-hot', 22994),
#  ('shakes', 1082),
#  ('shellfish', 15143),
#  ('short-grain-rice', 698),
#  ('shrimp', 8877),
#  ('shrimp-main-dish', 2),
#  ('side-dishes', 52861),
#  ('side-dishes-beans', 2),
#  ('simply-potatoes', 1211),
#  ('simply-potatoes2', 10),
#  ('slow-cooker', 2),
#  ('small-appliance', 14855),
#  ('smoker', 354),
#  ('smoothies', 3395),
#  ('snacks', 16640),
#  ('snacks-kid-friendly', 1),
#  ('snacks-sweet', 1),
#  ('sole-and-flounder', 401),
#  ('somalian', 15),
#  ('soul', 396),
#  ('soups-beans', 1),
#  ('soups-crock-pot', 1),
#  ('soups-stews', 27377),
#  ('sourdough', 212),
#  ('south-african', 501),
#  ('south-american', 2416),
#  ('south-west-pacific', 6708),
#  ('southern-united-states', 14246),
#  ('southwestern-united-states', 6572),
#  ('soy-tofu', 2390),
#  ('spaghetti', 3424),
#  ('spaghetti-sauce', 3),
#  ('spanish', 2128),
#  ('spicy', 14783),
#  ('spinach', 3675),
#  ('spreads', 4901),
#  ('spreads-fruit', 1),
#  ('spring', 6927),
#  ('squash', 7350),
#  ('squid', 216),
#  ('st-patricks-day', 1423),
#  ('steak', 1936),
#  ('steaks', 2298),
#  ('steam', 782),
#  ('stews', 2885),
#  ('stews-poultry', 1),
#  ('stir-fry', 2944),
#  ('stocks', 936),
#  ('stove-top', 37738),
#  ('strawberries', 4503),
#  ('strawberries-desserts', 1),
#  ('stuffings-dressings', 1589),
#  ('sudanese', 23),
#  ('sugar', 1),
#  ('sugar-cookies', 91),
#  ('summer', 18522),
#  ('super-bowl', 332),
#  ('superbowl', 3182),
#  ('swedish', 648),
#  ('sweet', 21271),
#  ('sweet-sauces', 1758),
#  ('swiss', 567),
#  ('szechuan', 232),
#  ('tarts', 1463),
#  ('taste-mood', 98046),
#  ('technique', 20961),
#  ('tempeh', 114),
#  ('tex-mex', 2780),
#  ('thai', 2612),
#  ('thanksgiving', 8346),
#  ('tilapia', 546),
#  ('time-to-make', 483507),
#  ('to-go', 33029),
#  ('toddler-friendly', 9824),
#  ('tomato-sauce', 1),
#  ('tomatoes', 11562),
#  ('tomatoes-sauces', 1),
#  ('tortilla-soup', 1),
#  ('tropical-fruit', 10239),
#  ('trout', 273),
#  ('tuna', 2973),
#  ('turkey', 5496),
#  ('turkey-breasts', 671),
#  ('turkey-burgers', 139),
#  ('turkey-gravy', 2),
#  ('turkish', 469),
#  ('unprocessed-freezer', 90),
#  ('valentines-day', 4385),
#  ('veal', 681),
#  ('vegan', 19919),
#  ('vegetable oil', 1),
#  ('vegetable oil recipe', 1),
#  ('vegetables', 105869),
#  ('vegetarian', 68955),
#  ('veggie-burgers', 143),
#  ('venezuelan', 78),
#  ('very-low-carbs', 20525),
#  ('vietnamese', 706),
#  ('water', 1),
#  ('water-bath', 719),
#  ('wedding', 1890),
#  ('weeknight', 45664),
#  ('welsh', 347),
#  ('wheat-bread', 1),
#  ('white cake mix', 1),
#  ('white-rice', 2087),
#  ('whitefish', 121),
#  ('whole-chicken', 2264),
#  ('whole-duck', 116),
#  ('whole-turkey', 406),
#  ('wild-game', 1212),
#  ('wings', 1234),
#  ('winter', 13682),
#  ('yams-sweet-potatoes', 3190),
#  ('yeast', 5311),
#  ('zucchini', 576)]

# %% [markdown]
# ### Adding Features/Columns

# %%
# maybe no need muna coz lots of preferences to consider?

# %% [markdown]
# ## Modelling
